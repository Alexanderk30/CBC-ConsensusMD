# %%
import anthropic
from datasets import load_dataset
from dotenv import load_dotenv
import os
from datasets import load_from_disk
#python3 -m pip install for any installations

# %%
load_dotenv()
client = anthropic.Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))


dataset = load_from_disk("diagnosis_arena_data")
type(dataset)
# Out:
# datasets.arrow_dataset.Dataset

# %%
df = dataset.to_pandas()

# %%
df.head()
# Out:
#    id                                   Case Information  \
# 0   1  A woman in her early 70s presented with a soli...
# 1   2  A previously healthy man in his 30s presented ...
# 2   3  A female patient in her early 50s presented wi...
# 3   4  A female patient in her late 20s presented wit...
# 4   5  A teenage girl presented with several months o...
#
#                                 Physical Examination  \
# 0  Physical findings revealed an ill-defined, inf...
# 1  Tender black spots on the scrotum were observe...
# 2  Multiple bluish, partially keratotic papules a...
# 3  Multiple firm, nonscaly, purple erythematous p...
# 4  On examination, a left nasal mass was noted. M...
#
#                                     Diagnostic Tests  \
# 0  - Imaging Studies:    Brain MRI Title: Paramed...
# 1  - Laboratory Tests: Peripheral blood cultures ...
# 2  - Sonography: Demonstrated intradermal slow-fl...
# 3  - Histopathological examination:    - Thin-wal...
# 4  - Imaging Studies:    CT scan (without and wit...
#
#                                      Final Diagnosis  \
# 0              Cutaneous meningeal heterotopia (CMH)
# 1  Scrotal ulceration secondary to induction chem...
# 2          Familial cerebral cavernous malformations
# 3                      Microvenular hemangioma (MVH)
# 4  Left maxillary giant cell reparative granuloma...
#
#                                              Options Right Option
# 0  {'A': 'Cutaneous meningeal heterotopia (CMH)',...            A
# 1  {'A': 'Pyoderma gangrenosum', 'B': 'Scrotal ul...            B
# 2  {'A': 'Cerebral Cavernous Malformations (CCM)'...            C
# 3  {'A': 'Epithelioid hemangioma', 'B': 'Morpheaf...            C
# 4  {'A': 'Ossifying Fibroma', 'B': 'Giant cell tu...            D
